# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
from sklearn import datasets

# %%
iris=pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.sample(10)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 13            4.3          3.0           1.1          0.1      Setosa
# 97            6.2          2.9           4.3          1.3  Versicolor
# 38            4.4          3.0           1.3          0.2      Setosa
# 32            5.2          4.1           1.5          0.1      Setosa
# 111           6.4          2.7           5.3          1.9   Virginica
# 139           6.9          3.1           5.4          2.1   Virginica
# 17            5.1          3.5           1.4          0.3      Setosa
# 95            5.7          3.0           4.2          1.2  Versicolor
# 10            5.4          3.7           1.5          0.2      Setosa
# 112           6.8          3.0           5.5          2.1   Virginica

# %%
le = LabelEncoder()

# %%
iris['variety']=le.fit_transform(iris['variety'])
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width  variety
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
iris.sample(10)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 149           5.9          3.0           5.1          1.8        2
# 112           6.8          3.0           5.5          2.1        2
# 15            5.7          4.4           1.5          0.4        0
# 123           6.3          2.7           4.9          1.8        2
# 117           7.7          3.8           6.7          2.2        2
# 49            5.0          3.3           1.4          0.2        0
# 8             4.4          2.9           1.4          0.2        0
# 0             5.1          3.5           1.4          0.2        0
# 146           6.3          2.5           5.0          1.9        2
# 119           6.0          2.2           5.0          1.5        2

# %%
x=iris.drop(columns='variety')
y=iris['variety']
x.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: variety, dtype: int32

# %%
y.shape
# Out:
# (150,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,stratify=y)

# %%
clf = LogisticRegression(multi_class='ovr')

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
y_pred_train = clf.predict(x_train)
y_pred_train
# Out:
# array([2, 0, 2, 0, 0, 1, 1, 1, 2, 2, 2, 1, 2, 2, 2, 2, 0, 2, 2, 1, 1, 0,
#        1, 0, 0, 0, 0, 2, 0, 2, 2, 1, 2, 0, 1, 0, 2, 2, 2, 0, 2, 0, 2, 0,
#        0, 0, 0, 2, 1, 1, 2, 1, 0, 2, 0, 0, 2, 1, 0, 0, 1, 0, 2, 1, 0, 2,
#        2, 1, 1, 0, 2, 0, 1, 1, 0, 1, 2, 2, 0, 2, 0, 1, 1, 0, 2, 1, 2, 0,
#        1, 0, 1, 2, 1, 2, 2, 2, 2, 1, 2, 1, 1, 2, 0, 1, 0, 1, 1, 0, 2, 0,
#        1, 2, 1, 2, 1, 0, 0, 1, 0, 2])

# %%
y_pred_test = clf.predict(x_test)
y_pred_test
# Out:
# array([2, 0, 1, 1, 1, 1, 2, 2, 2, 0, 2, 1, 2, 0, 2, 0, 0, 0, 2, 2, 1, 0,
#        0, 2, 0, 0, 2, 1, 2, 1])

# %%
accuracy_score(y_train,y_pred_train)
# Out:
# 0.95

# %%
accuracy_score(y_test,y_pred_test)
# Out:
# 0.8666666666666667
